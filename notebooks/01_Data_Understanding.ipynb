# %% [markdown]
# # Ecommerce Sales Dashboard
#
# ## Notebook 01 – Data Understanding
#
# ### Author
# Divya Sesilia
#
# ### Project
# End-to-End Data Analytics Project using SQL, Python, Excel, and Power BI
#
# ### Dataset
#
# Superstore Sales Dataset
#
# ### Tools Used
#
# - Python
# - Pandas
# - Jupyter Notebook
#
# ### Notebook Version
#
# 1.0
#
# ### Objective
#
# The objective of this notebook is to understand the dataset before performing any data cleaning or analysis.
#
# ### Tasks
#
# - Load the dataset
# - Explore the dataset structure
# - Check rows and columns
# - Identify data types
# - Find missing values
# - Find duplicate records
# - Generate descriptive statistics
# - Record observations

# %% [markdown]
# ## Load Required Library
#
# Pandas is used to load, manipulate, and analyze tabular datasets.

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset
#
# Load the Superstore dataset into a Pandas DataFrame.

# %%
df = pd.read_csv("../data/raw/superstore.csv")

# %%
# Display the first five records
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   12/6/2016   16/6/2016    Second Class    DV-13045
# 3       4  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
rows, columns = df.shape

print(f"Number of Rows    : {rows}")
print(f"Number of Columns : {columns}")
# Out:
# Number of Rows    : 9994
# Number of Columns : 21

# %%
print("Column Names:\n")

for col in df.columns:
    print(col)
# Out:
# Column Names:
#
# Row ID
# Order ID
# Order Date
# Ship Date
# Ship Mode
# Customer ID
# Customer Name
# Segment
# Country
# City
# State
# Postal Code
# Region
# Product ID
# Category
# Sub-Category
# Product Name
# Sales
# Quantity
# Discount
# Profit

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ## Initial Observations
#
# - The dataset contains **9,994 records** and **21 columns**.
# - There are **no missing values** in any column.
# - The dataset includes customer, product, sales, shipping, and regional information.
# - `Order Date` and `Ship Date` are stored as text (`object`) and should be converted to datetime.
# - `Sales`, `Profit`, and `Discount` are numerical columns that will be used for business analysis.
# - The dataset is clean enough to begin exploratory analysis after converting the date columns.

# %%
# Generate descriptive statistics for numerical columns
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# ## Statistical Summary
#
# ### Observations
#
# - Average Sales per Order: 229.86
# - Average Profit per Order: 28.66
# - Maximum Discount Offered: 80%
# - Some orders incur significant losses.
# - Sales values vary widely, indicating the presence of high-value orders.

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ## Missing Values Analysis
#
# There are no missing values in the dataset.
#
# The dataset is complete and ready for further analysis.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate Records Analysis
#
# No duplicate records were found.
#
# The dataset does not require duplicate removal.

# %%
df.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9231    9232  CA-2014-148383  27/12/2014  31/12/2014  Standard Class
# 9049    9050  CA-2014-124513   21/9/2014   25/9/2014  Standard Class
# 9839    9840  US-2016-125402   25/9/2016   1/10/2016  Standard Class
# 4023    4024  CA-2017-130764  27/10/2017  28/10/2017     First Class
# 9704    9705  CA-2017-147032   31/7/2017    4/8/2017  Standard Class
#
#      Customer ID   Customer Name      Segment        Country           City  \
# 9231    RP-19390    Resi Pölking     Consumer  United States        Phoenix
# 9049    SL-20155  Sara Luxemburg  Home Office  United States  New York City
# 9839    DL-12865      Dan Lawera     Consumer  United States     Long Beach
# 4023    JO-15145   Jack O'Briant    Corporate  United States  San Francisco
# 9704    LB-16795  Laurel Beltran  Home Office  United States     Wilmington
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## Random Sample Review
#
# Randomly inspecting records helps verify that the dataset appears consistent and contains realistic business information.
#
# This confirms that the data structure is suitable for further analysis.

# %% [markdown]
# # Conclusion
#
# ## Summary
#
# - Successfully loaded the Superstore dataset.
# - Verified that the dataset contains **9,994 rows** and **21 columns**.
# - Confirmed there are **no missing values**.
# - Confirmed there are **no duplicate records**.
# - Identified that **Order Date** and **Ship Date** need conversion to datetime.
# - Identified the key business metrics: Sales, Profit, Quantity, and Discount.
#
# ## Next Steps
#
# In the next notebook, we will:
#
# - Convert date columns to datetime.
# - Validate data types.
# - Prepare a cleaned dataset.
# - Export the cleaned dataset for SQL, Excel, and Power BI analysis.
